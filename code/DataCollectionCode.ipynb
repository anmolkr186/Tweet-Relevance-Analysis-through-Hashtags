# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#don't run this part
# %cd gdrive/My\ Drive/data
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/data'
# /content/gdrive/My Drive/data

# %%
import tweepy
import json
import csv

# %%
api_key = 'ywUuTkAn98KxbFsBzNq0uxxxx'
api_secret_key = 'vstOzvoaze7BGbvtsQmvimV2uhiP2mfwAojlixROoEbXb3xxxx'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAI49NwEAAAAA4RpR05iikoszLBd6aaELZMijMPo%3D1nv3TNAIsHyDLRasFQygjkNab7vKRGduKEFSLxxxxxxxxxxxx'
access_token = '1362354453655867396-itrqn64SZsSTft6c71pTVpTnxxxxx'
access_secret = '3ubekZSve0EY7Jr2D7p7d9sEFHGkbBbpOpV2F81N5xxxx'

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)

# %%
auth

# %%
try:
    redirect_url = auth.get_authorization_url()
    print(redirect_url)
except tweepy.TweepError:
    print('Error! Failed to get request token.')
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=38I6QgAAAAABNz2OAAABeF_AZrk

# %%
import tweepy
#connecting to tweepy API
auth = tweepy.OAuthHandler(api_key, api_secret_key)
# auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# public_tweets = api.home_timeline()
# for tweet in public_tweets:
    # print(tweet)

# %%
res = api.search(q= '#WorldPoetryDay', count = 20000, lang = 'en', tweet_mode="extended") #collecting tweets of WorldPoetryDay hashtag.
len(res)
# Out:
# 100

# %%
 key = res[-1]._json.keys() #getting all the keys
# for i in key:
#   print(i)

# %%
filename = "tweets12.csv" #saving the data collected in .csv and .json format
    
with open(filename, 'w') as csvfile:  
    csvwriter = csv.writer(csvfile)   
    csvwriter.writerow(key)
    for i in res:
      csvwriter.writerow(i._json.values())  
      print(i._json.values())
with open('Martyr12.json', 'w', encoding='utf-8') as f:
  for i in res:
    json.dump(i._json, f, indent = 4, ensure_ascii=False)
# Out:
# dict_values(['Tue Mar 23 19:32:47 +0000 2021', 1374444032374362120, '1374444032374362120', 'RT @rad_R_: Sidharth &amp; his fav freedom fighter भगत सिंह trending together ❤️\n\nKoi comparison hi nahi I knw..Bt it feels gud to see Sidharth…', False, [0, 144], {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'rad_R_', 'name': 'Radhika', 'id': 2880586034, 'id_str': '2880586034', 'indices': [3, 10]}], 'urls': []}, {'iso_language_code': 'en', 'result_type': 'recent'}, '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', None, None, None, None, None, {'id': 1061230188564889600, 'id_str': '1061230188564889600', 'name': '❤❤SUSMITA', 'screen_name': 'Sidjen12891', 'location': '', 'description': '❤.Not a stan Account..', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1425, 'friends_count': 2045, 'listed_count': 1, 'created_at': 'Sat Nov 10 12:12:48 +0000 2018', 'favourites_count': 93406, 'utc_offs
# ...
